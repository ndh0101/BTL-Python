# %%
import pandas as pd
df = pd.read_csv('D:\\pythonptit\\results1.csv')
df.iloc[:, 5:] = df.iloc[:, 5:].replace(',', '', regex=True)
df.iloc[:, 4:] = df.iloc[:, 4:].apply(pd.to_numeric, errors='coerce')

# %%
for x in df.columns[4:]:
    df_copy =df.copy()
    tmp =df_copy[['Player',x]].sort_values(x)
    tmp.dropna(axis=0, inplace=True)
    print(f'3 cầu thủ có {x} cao nhất')
    display(tmp[-3:][::-1])
    print(f'3 cầu thủ có {x} thấp nhất')
    display(tmp[:3])
# Out:
# 3 cầu thủ có Age cao nhất
#                Player  Age
# 492  Łukasz Fabiański   38
# 47       Ashley Young   38
# 446      Thiago Silva   38
# 3 cầu thủ có Age thấp nhất
#              Player  Age
# 277    Leon Chiwome   17
# 284     Lewis Miley   17
# 482  Wilson Odobert   18
# 3 cầu thủ có MP-Playing_Time-standard_stats cao nhất
#                Player  MP-Playing_Time-standard_stats
# 210   James Tarkowski                              38
# 346      Moussa Diaby                              38
# 228  Joachim Andersen                              38
# 3 cầu thủ có MP-Playing_Time-standard_stats thấp nhất
#             Player  MP-Playing_Time-standard_stats
# 320  Matheus Nunes                               2
# 358    Neal Maupay                               2
# 188     Ionuț Radu                               2
# 3 cầu thủ có Starts-Playing_Time-standard_stats cao nhất
#               Player  Starts-Playing_Time-standard_stats
# ...

# %%
import matplotlib.pyplot as plt
df3= df.copy()

print("Phân bố của mỗi chỉ số của các cầu thủ trong toàn giải")
print("")

for i,x in enumerate(df3.columns[4:]):
    print(f"phân bố của {x}")
    df_copy =df.copy()
    tmp =df_copy[x]
    tmp.dropna(axis=0,inplace=True)
    plt.hist(tmp)
    plt.xlabel(x)
    plt.ylabel("Frequency")
    plt.show()
# Out:
# Phân bố của mỗi chỉ số của các cầu thủ trong toàn giải
#
# phân bố của Age
# phân bố của MP-Playing_Time-standard_stats
# phân bố của Starts-Playing_Time-standard_stats
# phân bố của Min-Playing_Time-standard_stats
# phân bố của 90s-Playing_Time-standard_stats
# phân bố của Gls-Performace-standard_stats
# phân bố của Ast-Performace-standard_stats
# phân bố của G+A-Performace-standard_stats
# phân bố của G-PK-Performace-standard_stats
# phân bố của PK-Performace-standard_stats
# phân bố của PKatt-Performace-standard_stats
# phân bố của CrdY-Performace-standard_stats
# phân bố của CrdR-Performace-standard_stats
# phân bố của xG-Expected-standard_stats
# phân bố của npxG-Expected-standard_stats
# phân bố của xAG-Expected-standard_stats
# phân bố của npxG+xAG-Expected-standard_stats
# phân bố của PrgC-Progression-standard_stats
# phân bố của PrgP-Progression-standard_stats
# phân bố của PrgR-Progression-standard_stats
# ...
